# %%
import os
import warnings
from pathlib import Path
import requests

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential,load_model
from keras.layers import LSTM,Dense
from keras.backend import clear_session
from keras.metrics import RootMeanSquaredError
import tensorflow as tf

warnings.simplefilter('ignore')
plt.style.use('fivethirtyeight')

# %%
data_dir = Path('../data')

df = pd.read_csv(
    data_dir / 'msft_pretreated_with_dates.csv',
    index_col='Date'
).drop('Unnamed: 0', axis=1)

cols = df.columns
index = df.index

# %% [markdown]
# #### Prepare the Data for LSTM

# %%
def create_dataset(dataset,window_size):
    X,y = [],[]
    for i in range(len(dataset) - window_size):
        X.append(dataset[i: i + window_size,:-1])
        y.append(dataset[i + window_size,0])

    return np.array(X),np.array(y)

# %%
dataset = df.values
dataset = dataset.astype('float32')
window_size = 60

#normalize
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataset)

# train test split
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train,test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

print(f'Train shape {train.shape}, test shape {test.shape}')

X_train,y_train = create_dataset(train,window_size=window_size)
X_test,y_test = create_dataset(test,window_size=window_size)

print(f'X_train shape {X_train.shape} , y_train shape {y_train.shape}')
print(f'X_train shape {X_test.shape} , y_train shape {y_test.shape}')
# Out:
# Train shape (3967, 8), test shape (1954, 8)
# X_train shape (3907, 60, 7) , y_train shape (3907,)
# X_train shape (1894, 60, 7) , y_train shape (1894,)

# %%
df_test = df.copy()
df_test = df_test.reset_index()

df_test = df_test.iloc[train_size:len(dataset),:]
df_test = df_test.iloc[60:]

dates = df_test['Date'].tolist()

print(dates)
# Out:
# ['2016-01-06', '2016-01-07', '2016-01-08', '2016-01-11', '2016-01-12', '2016-01-13', '2016-01-14', '2016-01-15', '2016-01-19', '2016-01-20', '2016-01-21', '2016-01-22', '2016-01-25', '2016-01-26', '2016-01-27', '2016-01-28', '2016-01-29', '2016-02-01', '2016-02-02', '2016-02-03', '2016-02-04', '2016-02-05', '2016-02-08', '2016-02-09', '2016-02-10', '2016-02-11', '2016-02-12', '2016-02-16', '2016-02-17', '2016-02-18', '2016-02-19', '2016-02-22', '2016-02-23', '2016-02-24', '2016-02-25', '2016-02-26', '2016-02-29', '2016-03-01', '2016-03-02', '2016-03-03', '2016-03-04', '2016-03-07', '2016-03-08', '2016-03-09', '2016-03-10', '2016-03-11', '2016-03-14', '2016-03-15', '2016-03-16', '2016-03-17', '2016-03-18', '2016-03-21', '2016-03-22', '2016-03-23', '2016-03-24', '2016-03-28', '2016-03-29', '2016-03-30', '2016-03-31', '2016-04-01', '2016-04-04', '2016-04-05', '2016-04-06', '2016-04-07', '2016-04-08', '2016-04-11', '2016-04-12', '2016-04-13', '2016-04-14', '2016-04-15', '2016-04-18', '2016-04-19', '2016-04-20', '2016-04-21', '2016-04-22', '2016-04-25', '2016-04-26', '2016-04-27', '2016-04-28', '2016-04-29', '2016-05-02', '2016-05-03', '2016-05-04', '2016-05-05', '2016-05-06', '2016-05-09', '2016-05-10', '2016-05-11', '2016-05-12', '2016-05-13', '2016-05-16', '2016-05-17', '2016-05-18', '2016-05-19', '2016-05-20', '2016-05-23', '2016-05-24', '2016-05-25', '2016-05-26', '2016-05-27', '2016-05-31', '2016-06-01', '2016-06-02', '2016-06-03', '2016-06-06', '2016-06-07', '2016-06-08', '2016-06-09', '2016-06-10', '2016-06-13', '2016-06-14', '2016-06-15', '2016-06-16', '2016-06-17', '2016-06-20', '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24', '2016-06-27', '2016-06-28', '2016-06-29', '2016-06-30', '2016-07-01', '2016-07-05', '2016-07-06', '2016-07-07', '2016-07-08', '2016-07-11', '2016-07-12', '2016-07-13', '2016-07-14', '2016-07-15', '2016-07-18', '2016-07-19', '2016-07-20', '2016-07-21', '2016-07-22', '2016-07-25', '2016-07-26', '2016-07-27', '2016-07-28', '2016-07-29', '2016-08-01', '2016-08-02', '2016-08-03', '2016-08-04', '2016-08-05', '2016-08-08', '2016-08-09', '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-15', '2016-08-16', '2016-08-17', '2016-08-18', '2016-08-19', '2016-08-22', '2016-08-23', '2016-08-24', '2016-08-25', '2016-08-26', '2016-08-29', '2016-08-30', '2016-08-31', '2016-09-01', '2016-09-02', '2016-09-06', '2016-09-07', '2016-09-08', '2016-09-09', '2016-09-12', '2016-09-13', '2016-09-14', '2016-09-15', '2016-09-16', '2016-09-19', '2016-09-20', '2016-09-21', '2016-09-22', '2016-09-23', '2016-09-26', '2016-09-27', '2016-09-28', '2016-09-29', '2016-09-30', '2016-10-03', '2016-10-04', '2016-10-05', '2016-10-06', '2016-10-07', '2016-10-10', '2016-10-11', '2016-10-12', '2016-10-13', '2016-10-14', '2016-10-17', '2016-10-18', '2016-10-19', '2016-10-20', '2016-10-21', '2016-10-24', '2016-10-25', '2016-10-26', '2016-10-27', '2016-10-28', '2016-10-31', '2016-11-01', '2016-11-02', '2016-11-03', '2016-11-04', '2016-11-07', '2016-11-08', '2016-11-09', '2016-11-10', '2016-11-11', '2016-11-14', '2016-11-15', '2016-11-16', '2016-11-17', '2016-11-18', '2016-11-21', '2016-11-22', '2016-11-23', '2016-11-25', '2016-11-28', '2016-11-29', '2016-11-30', '2016-12-01', '2016-12-02', '2016-12-05', '2016-12-06', '2016-12-07', '2016-12-08', '2016-12-09', '2016-12-12', '2016-12-13', '2016-12-14', '2016-12-15', '2016-12-16', '2016-12-19', '2016-12-20', '2016-12-21', '2016-12-22', '2016-12-23', '2016-12-27', '2016-12-28', '2016-12-29', '2016-12-30', '2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06', '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12', '2017-01-13', '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20', '2017-01-23', '2017-01-24', '2017-01-25', '2017-01-26', '2017-01-27', '2017-01-30', '2017-01-31', '2017-02-01', '2017-02-02', '2017-02-03', '2017-02-06', '2017-02-07', '2017-02-08', '2017-02-09', '2017-02-10', '2017-02-13', '2017-02-14', '2017-02-15', '2017-02-16', '2017-02-17', '2017-02-21', '2017-02-22', '2017-02- ...

# %%
clear_session()

model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])),
    LSTM(50,return_sequences=False),
    Dense(25),
    Dense(1)
])

model.compile(
    optimizer='Adam',
    loss='mean_squared_error',
    metrics=[RootMeanSquaredError()]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 50)            11600
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 25)                1275
#
#  dense_1 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 33,101
# Trainable params: 33,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,
                    y_train,
                    batch_size=1,
                    validation_data=(X_test,y_test),
                    verbose=2,
                    epochs=100)

model.save('lstm_pretreated_features.h5')
# Out:
# Epoch 1/100
# 3907/3907 - 39s - loss: 4.7568e-04 - root_mean_squared_error: 0.0218 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344 - 39s/epoch - 10ms/step
# Epoch 2/100
# 3907/3907 - 32s - loss: 1.0435e-04 - root_mean_squared_error: 0.0102 - val_loss: 9.0180e-05 - val_root_mean_squared_error: 0.0095 - 32s/epoch - 8ms/step
# Epoch 3/100
# 3907/3907 - 36s - loss: 6.9269e-05 - root_mean_squared_error: 0.0083 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342 - 36s/epoch - 9ms/step
# Epoch 4/100
# 3907/3907 - 36s - loss: 5.7614e-05 - root_mean_squared_error: 0.0076 - val_loss: 3.6563e-05 - val_root_mean_squared_error: 0.0060 - 36s/epoch - 9ms/step
# Epoch 5/100
# 3907/3907 - 36s - loss: 5.0579e-05 - root_mean_squared_error: 0.0071 - val_loss: 3.2236e-05 - val_root_mean_squared_error: 0.0057 - 36s/epoch - 9ms/step
# Epoch 6/100
# 3907/3907 - 37s - loss: 3.9374e-05 - root_mean_squared_error: 0.0063 - val_loss: 1.7028e-05 - val_root_mean_squared_error: 0.0041 - 37s/epoch - 9ms/step
# Epoch 7/100
# 3907/3907 - 37s - loss: 3.8218e-05 - root_mean_squared_error: 0.0062 - val_loss: 8.7825e-06 - val_root_mean_squared_error: 0.0030 - 37s/epoch - 10ms/step
# Epoch 8/100
# 3907/3907 - 32s - loss: 2.7674e-05 - root_mean_squared_error: 0.0053 - val_loss: 4.5322e-05 - val_root_mean_squared_error: 0.0067 - 32s/epoch - 8ms/step
# Epoch 9/100
# 3907/3907 - 36s - loss: 2.2651e-05 - root_mean_squared_error: 0.0048 - val_loss: 3.9832e-05 - val_root_mean_squared_error: 0.0063 - 36s/epoch - 9ms/step
# Epoch 10/100
# 3907/3907 - 36s - loss: 1.6983e-05 - root_mean_squared_error: 0.0041 - val_loss: 3.6286e-05 - val_root_mean_squared_error: 0.0060 - 36s/epoch - 9ms/step
# Epoch 11/100
# 3907/3907 - 32s - loss: 2.5337e-05 - root_mean_squared_error: 0.0050 - val_loss: 3.9831e-04 - val_root_mean_squared_error: 0.0200 - 32s/epoch - 8ms/step
# Epoch 12/100
# 3907/3907 - 32s - loss: 1.5150e-05 - root_mean_squared_error: 0.0039 - val_loss: 3.1267e-05 - val_root_mean_squared_error: 0.0056 - 32s/epoch - 8ms/step
# Epoch 13/100
# 3907/3907 - 32s - loss: 1.4442e-05 - root_mean_squared_error: 0.0038 - val_loss: 4.3224e-06 - val_root_mean_squared_error: 0.0021 - 32s/epoch - 8ms/step
# Epoch 14/100
# 3907/3907 - 31s - loss: 2.1548e-05 - root_mean_squared_error: 0.0046 - val_loss: 1.2783e-05 - val_root_mean_squared_error: 0.0036 - 31s/epoch - 8ms/step
# Epoch 15/100
# 3907/3907 - 32s - loss: 1.6107e-05 - root_mean_squared_error: 0.0040 - val_loss: 7.8901e-06 - val_root_mean_squared_error: 0.0028 - 32s/epoch - 8ms/step
# Epoch 16/100
# 3907/3907 - 32s - loss: 1.4188e-05 - root_mean_squared_error: 0.0038 - val_loss: 5.1009e-06 - val_root_mean_squared_error: 0.0023 - 32s/epoch - 8ms/step
# Epoch 17/100
# 3907/3907 - 36s - loss: 1.4043e-05 - root_mean_squared_error: 0.0037 - val_loss: 2.3334e-05 - val_root_mean_squared_error: 0.0048 - 36s/epoch - 9ms/step
# Epoch 18/100
# 3907/3907 - 32s - loss: 1.3818e-05 - root_mean_squared_error: 0.0037 - val_loss: 2.0228e-05 - val_root_mean_squared_error: 0.0045 - 32s/epoch - 8ms/step
# Epoch 19/100
# 3907/3907 - 36s - loss: 1.3117e-05 - root_mean_squared_error: 0.0036 - val_loss: 3.2314e-05 - val_root_mean_squared_error: 0.0057 - 36s/epoch - 9ms/step
# Epoch 20/100
# 3907/3907 - 36s - loss: 1.6284e-05 - root_mean_squared_error: 0.0040 - val_loss: 3.9085e-05 - val_root_mean_squared_error: 0.0063 - 36s/epoch - 9ms/step
# Epoch 21/100
# 3907/3907 - 32s - loss: 1.0261e-05 - root_mean_squared_error: 0.0032 - val_loss: 8.2882e-05 - val_root_mean_squared_error: 0.0091 - 32s/epoch - 8ms/step
# Epoch 22/100
# 3907/3907 - 32s - loss: 1.1738e-05 - root_mean_squared_error: 0.0034 - val_loss: 1.1879e-04 - val_root_mean_squared_error: 0.0109 - 32s/epoch - 8ms/step
# Epoch 23/100
# 3907/3907 - 36s - loss: 1.3622e-05 - root_mean_squared_error: 0.0037 - val_loss: 6.4470e-05 - val_root_mean_squared_error: 0.0080 - 36s/epoch - 9ms/step
# Epoch 24/100
# 3907/3907 - 31s - loss: 1.2097e-05 - root_mean_squared_error: 0.0035 - val_loss: 7.3686e-05 - val_root_mean_squared_error: 0.0086 - 31s/epoch - 8ms/step
# Epoch 25/100
# 3907/3907 - 32s - loss: 1.0944e-05 - root_mean_squared_error: 0.0033 - val_loss: 3.5709e-05 - val_root_mean_squared_error: 0.0060 - 32s/epoch - 8ms/step
# Epoch 26/100
# 3907/3907 - 32s - loss: 1.3437e-05 - root_mean_squared_error: 0.0037 - val_loss: 1.1304e-04 - val_root_mean_squared_error: 0.0106 - 32s/epoch - 8ms/step
# Epoch 27/100
# 3907/3907 - 36s - loss: 1.2464e-05 - root_mean_squared_error: 0.0035 - val_loss: 1.0142e-04 - val_root_mean_squared_error: 0.0101 - 36s/epoch - 9ms/step
# Epoch 28/100
# 3907/3907 - 31s - loss: 8.4643e-06 - root_mean_squared_error: 0.0029 - val_loss: 1.0664e-04 - val_root_mean_squared_error: 0.0103 - 31s/epoch - 8ms/step
# Epoch 29/100
# 3907/3907 - 32s - loss: 1.2008e-05 - root_mean_squared_error: 0.0035 - val_loss: 7.7525e-05 - val_root_mean_squared_error: 0.0088 - 32s/epoch - 8ms/step
# Epoch 30/100
# 3907/3907 - 32s - loss: 8.3548e-06 - root_mean_squared_error: 0.0029 - val_loss: 1.1234e-04 - val_root_mean_squared_error: 0.0106 - 32s/epoch - 8ms/step
# Epoch 31/100
# 3907/3907 - 32s - loss: 7.8762e-06 - root_mean_squared_error: 0.0028 - val_loss: 6.1705e-05 - val_root_mean_squared_error: 0.0079 - 32s/epoch - 8ms/step
# Epoch 32/100
# 3907/3907 - 32s - loss: 9.9208e-06 - root_mean_squared_error: 0.0031 - val_loss: 1.0995e-04 - val_root_mean_squared_error: 0.0105 - 32s/epoch - 8ms/step
# Epoch 33/100
# 3907/3907 - 36s - loss: 1.0433e-05 - root_mean_squared_error: 0.0032 - val_loss: 2.8132e-04 - val_root_mean_squared_error: 0.0168 - 36s/epoch - 9ms/step
# Epoch 34/100
# 3907/3907 - 36s - loss: 9.3036e-06 - root_mean_squared_error: 0.0031 - val_loss: 1.7520e-04 - val_root_mean_squared_error: 0.0132 - 36s/epoch - 9ms/step
# Epoch 35/100
# 3907/3907 - 31s - loss: 1.0288e-05 - root_mean_squared_error: 0.0032 - val_loss: 2.6467e-04 - val_root_mean_squared_error: 0.0163 - 31s/epoch - 8ms/step
# Epoch 36/100
# 3907/3907 - 32s - loss: 8.2776e-06 - root_mean_squared_error: 0.0029 - val_loss: 1.0336e-04 - val_root_mean_squared_error: 0.0102 - 32s/epoch - 8ms/step
# Epoch 37/100
# 3907/3907 - 36s - loss: 7.2048e-06 - root_mean_squared_error: 0.0027 - val_loss: 1.9847e-04 - val_root_mean_squared_error: 0.0141 - 36s/epoch - 9ms/step
# Epoch 38/100
# 3907/3907 - 36s - loss: 7.8613e-06 - root_mean_squared_error: 0.0028 - val_loss: 1.5505e-04 - val_root_mean_squared_error: 0.0125 - 36s/epoch - 9ms/step
# Epoch 39/100
# 3907/3907 - 32s - loss: 1.3746e-05 - root_mean_squared_error: 0.0037 - val_loss: 1.0156e-04 - val_root_mean_squared_error: 0.0101 - 32s/epoch - 8ms/step
# Epoch 40/100
# 3907/3907 - 31s - loss: 8.0305e-06 - root_mean_squared_error: 0.0028 - val_loss: 8.0343e-05 - val_root_mean_squared_error: 0.0090 - 31s/epoch - 8ms/step
# Epoch 41/100
# 3907/3907 - 36s - loss: 7.0329e-06 - root_mean_squared_error: 0.0027 - val_loss: 1.2268e-04 - val_root_mean_squared_error: 0.0111 - 36s/epoch - 9ms/step
# Epoch 42/100
# 3907/3907 - 32s - loss: 8.2379e-06 - root_mean_squared_error: 0.0029 - val_loss: 1.3550e-04 - val_root_mean_squared_error: 0.0116 - 32s/epoch - 8ms/step
# Epoch 43/100
# 3907/3907 - 36s - loss: 6.5467e-06 - root_mean_squared_error: 0.0026 - val_loss: 8.7523e-05 - val_root_mean_squared_error: 0.0094 - 36s/epoch - 9ms/step
# Epoch 44/100
# 3907/3907 - 36s - loss: 7.7754e-06 - root_mean_squared_error: 0.0028 - val_loss: 1.1331e-04 - val_root_mean_squared_error: 0.0106 - 36s/epoch - 9ms/step
# Epoch 45/100
# 3907/3907 - 36s - loss: 6.7221e-06 - root_mean_squared_error: 0.0026 - val_loss: 8.8009e-05 - val_root_mean_squared_error: 0.0094 - 36s/epoch - 9ms/step
# Epoch 46/100
# 3907/3907 - 36s - loss: 7.4901e-06 - root_mean_squared_error: 0.0027 - val_loss: 6.4001e-05 - val_root_mean_squared_error: 0.0080 - 36s/epoch - 9ms/step
# Epoch 47/100
# 3907/3907 - 36s - loss: 6.9102e-06 - root_mean_squared_error: 0.0026 - val_loss: 3.8529e-05 - val_root_mean_squared_error: 0.0062 - 36s/epoch - 9ms/step
# Epoch 48/100
# 3907/3907 - 36s - loss: 8.2084e-06 - root_mean_squared_error: 0.0029 - val_loss: 9.1877e-05 - val_root_mean_squared_error: 0.0096 - 36s/epoch - 9ms/step
# Epoch 49/100
# 3907/3907 - 36s - loss: 7.8996e-06 - root_mean_squared_error: 0.0028 - val_loss: 3.2782e-05 - val_root_mean_squared_error: 0.0057 - 36s/epoch - 9ms/step
# Epoch 50/100
# 3907/3907 - 36s - loss: 6.1258e-06 - root_mean_squared_error: 0.0025 - val_loss: 7.0757e-05 - val_root_mean_squared_error: 0.0084 - 36s/epoch - 9ms/step
# Epoch 51/100
# 3907/3907 - 36s - loss: 7.8929e-06 - root_mean_squared_error: 0.0028 - val_loss: 7.9620e-05 - val_root_mean_squared_error: 0.0089 - 36s/epoch - 9ms/step
# Epoch 52/100
# 3907/3907 - 36s - loss: 5.1327e-06 - root_mean_squared_error: 0.0023 - val_loss: 3.3357e-05 - val_root_mean_squared_error: 0.0058 - 36s/epoch - 9ms/step
# Epoch 53/100
# 3907/3907 - 36s - loss: 6.2759e-06 - root_mean_squared_error: 0.0025 - val_loss: 6.7003e-05 - val_root_mean_squared_error: 0.0082 - 36s/epoch - 9ms/step
# Epoch 54/100
# 3907/3907 - 32s - loss: 5.9509e-06 - root_mean_squared_error: 0.0024 - val_loss: 4.9746e-05 - val_root_mean_squared_error: 0.0071 - 32s/epoch - 8ms/step
# Epoch 55/100
# 3907/3907 - 36s - loss: 6.3260e-06 - root_mean_squared_error: 0.0025 - val_loss: 7.6015e-05 - val_root_mean_squared_error: 0.0087 - 36s/epoch - 9ms/step
# Epoch 56/100
# 3907/3907 - 32s - loss: 9.5146e-06 - root_mean_squared_error: 0.0031 - val_loss: 6.2678e-05 - val_root_mean_squared_error: 0.0079 - 32s/epoch - 8ms/step
# Epoch 57/100
# 3907/3907 - 32s - loss: 5.7757e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.9234e-05 - val_root_mean_squared_error: 0.0063 - 32s/epoch - 8ms/step
# Epoch 58/100
# 3907/3907 - 36s - loss: 5.7756e-06 - root_mean_squared_error: 0.0024 - val_loss: 3.7328e-05 - val_root_mean_squared_error: 0.0061 - 36s/epoch - 9ms/step
# Epoch 59/100
# 3907/3907 - 36s - loss: 5.4561e-06 - root_mean_squared_error: 0.0023 - val_loss: 1.3906e-04 - val_root_mean_squared_error: 0.0118 - 36s/epoch - 9ms/step
# Epoch 60/100
# 3907/3907 - 32s - loss: 6.6074e-06 - root_mean_squared_error: 0.0026 - val_loss: 2.3104e-04 - val_root_mean_squared_error: 0.0152 - 32s/epoch - 8ms/step
# Epoch 61/100
# 3907/3907 - 36s - loss: 6.1589e-06 - root_mean_squared_error: 0.0025 - val_loss: 3.9738e-05 - val_root_mean_squared_error: 0.0063 - 36s/epoch - 9ms/step
# Epoch 62/100
# 3907/3907 - 32s - loss: 4.5464e-06 - root_mean_squared_error: 0.0021 - val_loss: 6.6915e-05 - val_root_mean_squared_error: 0.0082 - 32s/epoch - 8ms/step
# Epoch 63/100
# 3907/3907 - 36s - loss: 5.8315e-06 - root_mean_squared_error: 0.0024 - val_loss: 7.0630e-05 - val_root_mean_squared_error: 0.0084 - 36s/epoch - 9ms/step
# Epoch 64/100
# 3907/3907 - 32s - loss: 5.9263e-06 - root_mean_squared_error: 0.0024 - val_loss: 8.9654e-05 - val_root_mean_squared_error: 0.0095 - 32s/epoch - 8ms/step
# Epoch 65/100
# 3907/3907 - 32s - loss: 4.3820e-06 - root_mean_squared_error: 0.0021 - val_loss: 4.9220e-05 - val_root_mean_squared_error: 0.0070 - 32s/epoch - 8ms/step
# Epoch 66/100
# 3907/3907 - 32s - loss: 5.4278e-06 - root_mean_squared_error: 0.0023 - val_loss: 6.2391e-05 - val_root_mean_squared_error: 0.0079 - 32s/epoch - 8ms/step
# Epoch 67/100
# 3907/3907 - 32s - loss: 5.8712e-06 - root_mean_squared_error: 0.0024 - val_loss: 1.1934e-04 - val_root_mean_squared_error: 0.0109 - 32s/epoch - 8ms/step
# Epoch 68/100
# 3907/3907 - 31s - loss: 5.1082e-06 - root_mean_squared_error: 0.0023 - val_loss: 1.6352e-04 - val_root_mean_squared_error: 0.0128 - 31s/epoch - 8ms/step
# Epoch 69/100
# 3907/3907 - 32s - loss: 4.9516e-06 - root_mean_squared_error: 0.0022 - val_loss: 7.6340e-05 - val_root_mean_squared_error: 0.0087 - 32s/epoch - 8ms/step
# Epoch 70/100
# 3907/3907 - 36s - loss: 4.7849e-06 - root_mean_squared_error: 0.0022 - val_loss: 1.1745e-04 - val_root_mean_squared_error: 0.0108 - 36s/epoch - 9ms/step
# Epoch 71/100
# 3907/3907 - 36s - loss: 5.5789e-06 - root_mean_squared_error: 0.0024 - val_loss: 5.9010e-05 - val_root_mean_squared_error: 0.0077 - 36s/epoch - 9ms/step
# Epoch 72/100
# 3907/3907 - 36s - loss: 4.3519e-06 - root_mean_squared_error: 0.0021 - val_loss: 9.9909e-05 - val_root_mean_squared_error: 0.0100 - 36s/epoch - 9ms/step
# Epoch 73/100
# 3907/3907 - 36s - loss: 4.9001e-06 - root_mean_squared_error: 0.0022 - val_loss: 3.3489e-05 - val_root_mean_squared_error: 0.0058 - 36s/epoch - 9ms/step
# Epoch 74/100
# 3907/3907 - 36s - loss: 4.5138e-06 - root_mean_squared_error: 0.0021 - val_loss: 3.5631e-05 - val_root_mean_squared_error: 0.0060 - 36s/epoch - 9ms/step
# Epoch 75/100
# 3907/3907 - 36s - loss: 5.3004e-06 - root_mean_squared_error: 0.0023 - val_loss: 1.1880e-04 - val_root_mean_squared_error: 0.0109 - 36s/epoch - 9ms/step
# Epoch 76/100
# 3907/3907 - 36s - loss: 4.4272e-06 - root_mean_squared_error: 0.0021 - val_loss: 1.6908e-04 - val_root_mean_squared_error: 0.0130 - 36s/epoch - 9ms/step
# Epoch 77/100
# 3907/3907 - 32s - loss: 4.8544e-06 - root_mean_squared_error: 0.0022 - val_loss: 7.7714e-05 - val_root_mean_squared_error: 0.0088 - 32s/epoch - 8ms/step
# Epoch 78/100
# 3907/3907 - 32s - loss: 5.1958e-06 - root_mean_squared_error: 0.0023 - val_loss: 4.9258e-05 - val_root_mean_squared_error: 0.0070 - 32s/epoch - 8ms/step
# Epoch 79/100
# 3907/3907 - 36s - loss: 4.3651e-06 - root_mean_squared_error: 0.0021 - val_loss: 1.4133e-04 - val_root_mean_squared_error: 0.0119 - 36s/epoch - 9ms/step
# Epoch 80/100
# 3907/3907 - 32s - loss: 3.9122e-06 - root_mean_squared_error: 0.0020 - val_loss: 1.9536e-04 - val_root_mean_squared_error: 0.0140 - 32s/epoch - 8ms/step
# Epoch 81/100
# 3907/3907 - 31s - loss: 5.9586e-06 - root_mean_squared_error: 0.0024 - val_loss: 1.4500e-04 - val_root_mean_squared_error: 0.0120 - 31s/epoch - 8ms/step
# Epoch 82/100
# 3907/3907 - 36s - loss: 4.2313e-06 - root_mean_squared_error: 0.0021 - val_loss: 7.5963e-05 - val_root_mean_squared_error: 0.0087 - 36s/epoch - 9ms/step
# Epoch 83/100
# 3907/3907 - 36s - loss: 3.9875e-06 - root_mean_squared_error: 0.0020 - val_loss: 1.2307e-04 - val_root_mean_squared_error: 0.0111 - 36s/epoch - 9ms/step
# Epoch 84/100
# 3907/3907 - 32s - loss: 4.1158e-06 - root_mean_squared_error: 0.0020 - val_loss: 1.9419e-04 - val_root_mean_squared_error: 0.0139 - 32s/epoch - 8ms/step
# Epoch 85/100
# 3907/3907 - 32s - loss: 5.0959e-06 - root_mean_squared_error: 0.0023 - val_loss: 2.1260e-04 - val_root_mean_squared_error: 0.0146 - 32s/epoch - 8ms/step
# Epoch 86/100
# 3907/3907 - 32s - loss: 4.6574e-06 - root_mean_squared_error: 0.0022 - val_loss: 2.0581e-04 - val_root_mean_squared_error: 0.0143 - 32s/epoch - 8ms/step
# Epoch 87/100
# 3907/3907 - 37s - loss: 3.5466e-06 - root_mean_squared_error: 0.0019 - val_loss: 1.0285e-04 - val_root_mean_squared_error: 0.0101 - 37s/epoch - 9ms/step
# Epoch 88/100
# 3907/3907 - 37s - loss: 4.2428e-06 - root_mean_squared_error: 0.0021 - val_loss: 1.0003e-04 - val_root_mean_squared_error: 0.0100 - 37s/epoch - 9ms/step
# Epoch 89/100
# 3907/3907 - 37s - loss: 4.2850e-06 - root_mean_squared_error: 0.0021 - val_loss: 3.2632e-04 - val_root_mean_squared_error: 0.0181 - 37s/epoch - 9ms/step
# Epoch 90/100
# 3907/3907 - 36s - loss: 4.8172e-06 - root_mean_squared_error: 0.0022 - val_loss: 7.6517e-05 - val_root_mean_squared_error: 0.0087 - 36s/epoch - 9ms/step
# Epoch 91/100
# 3907/3907 - 36s - loss: 3.4992e-06 - root_mean_squared_error: 0.0019 - val_loss: 1.0745e-04 - val_root_mean_squared_error: 0.0104 - 36s/epoch - 9ms/step
# Epoch 92/100
# 3907/3907 - 37s - loss: 3.7436e-06 - root_mean_squared_error: 0.0019 - val_loss: 1.1759e-04 - val_root_mean_squared_error: 0.0108 - 37s/epoch - 9ms/step
# Epoch 93/100
# 3907/3907 - 32s - loss: 3.8035e-06 - root_mean_squared_error: 0.0020 - val_loss: 1.2846e-04 - val_root_mean_squared_error: 0.0113 - 32s/epoch - 8ms/step
# Epoch 94/100
# 3907/3907 - 36s - loss: 3.7462e-06 - root_mean_squared_error: 0.0019 - val_loss: 9.0118e-05 - val_root_mean_squared_error: 0.0095 - 36s/epoch - 9ms/step
# Epoch 95/100
# 3907/3907 - 32s - loss: 3.1786e-06 - root_mean_squared_error: 0.0018 - val_loss: 2.0559e-04 - val_root_mean_squared_error: 0.0143 - 32s/epoch - 8ms/step
# Epoch 96/100
# 3907/3907 - 37s - loss: 3.3132e-06 - root_mean_squared_error: 0.0018 - val_loss: 5.4634e-05 - val_root_mean_squared_error: 0.0074 - 37s/epoch - 9ms/step
# Epoch 97/100
# 3907/3907 - 32s - loss: 4.2225e-06 - root_mean_squared_error: 0.0021 - val_loss: 1.1788e-04 - val_root_mean_squared_error: 0.0109 - 32s/epoch - 8ms/step
# Epoch 98/100
# 3907/3907 - 32s - loss: 4.8138e-06 - root_mean_squared_error: 0.0022 - val_loss: 1.2590e-04 - val_root_mean_squared_error: 0.0112 - 32s/epoch - 8ms/step
# Epoch 99/100
# 3907/3907 - 32s - loss: 3.0814e-06 - root_mean_squared_error: 0.0018 - val_loss: 1.7181e-04 - val_root_mean_squared_error: 0.0131 - 32s/epoch - 8ms/step
# Epoch 100/100
# 3907/3907 - 32s - loss: 3.7098e-06 - root_mean_squared_error: 0.0019 - val_loss: 7.5120e-05 - val_root_mean_squared_error: 0.0087 - 32s/epoch - 8ms/step

# %%
history_df = pd.DataFrame(history.history)

plt.rc(
    'lines',
    linewidth=2
)

fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,6),sharex=True)

history_df['loss'].plot(ax=ax1, label='Train loss')
history_df['val_loss'].plot(ax=ax1, label='Val loss')
ax1.legend()

history_df['root_mean_squared_error'].plot(ax=ax2, label='Train RMSE')
history_df['val_root_mean_squared_error'].plot(ax=ax2, label='Val RMSE')
ax2.legend()

plt.show()

# %%
model = load_model('../models/lstm_pretreated_features.h5')

fitted = model.predict(X_train)
preds = model.predict(X_test)

#inverse transform train,test
inv_train = pd.DataFrame(scaler.inverse_transform(train),columns=cols).iloc[60:,:].reset_index()
inv_test = pd.DataFrame(scaler.inverse_transform(test),columns=cols).iloc[60:,:].reset_index()

inv_train['Fitted MPN5P'] = fitted
inv_test['Preds MPN5P'] = preds

train_rmse = np.sqrt(mean_squared_error(inv_train['MPN5P'].values,inv_train['Fitted MPN5P'].values))
test_rmse = np.sqrt(mean_squared_error(inv_test['MPN5P'].values,inv_test['Preds MPN5P'].values))

print(f'Train RMSE: {train_rmse}')
print(f'Test RMSE: {test_rmse}')
# Out:
# 123/123 [==============================] - 4s 20ms/step
# 60/60 [==============================] - 1s 20ms/step
# Train RMSE: 1.2758517265319824
# Test RMSE: 1.169909954071045

# %%
fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,6))

ax1.plot(inv_train['MPN5P'].values, linewidth=2, label='Train')
ax1.plot(inv_train['Fitted MPN5P'].values, linewidth=1.5, label='Test')
ax1.legend()

ax2.plot(inv_test['MPN5P'].values, linewidth=2, label='Train')
ax2.plot(inv_test['Preds MPN5P'].values, linewidth=1.5, label='Test')
ax2.legend()

# %% [markdown]
# #### Target Plot Generator

# %%
def TPG_Trigger(scatter_x_value,
                scatter_y_value,
                scatter_x_label,
                scatter_y_label,
                ratio_x_value,
                ratio_y_value,
                ratio_x_label,
                ratio_y_label,
                comparison_x_value,
                comparison_y_value,
                comparison_x_label,
                comparison_y_label,
                dates,
                multiple_run_predictions_length,
                plot_name):
    headers={'Accept-Encoding': 'gzip, deflate, br','Content-Type': 'application/json','Accept': 'application/json','Connection': 'keep-alive','DNT': '1'}
    query = """
        query PlotMe(
            $scatter_x_value: [Float]!,
            $scatter_y_value: [Float]!,
            $scatter_x_label: String!,
            $scatter_y_label: String!,
            $ratio_x_value: [Float]!,
            $ratio_y_value: [Float]!,
            $ratio_x_label: String!,
            $ratio_y_label: String!,
            $comparison_x_value: [Float]!,
            $comparison_y_value: [Float]!,
            $comparison_x_label: String!,
            $comparison_y_label: String!,
            $dates: [String]!,
            $multiple_run_predictions_length: Int!,
            $plot_name: String!
        ) {
            plotme(
                scatter_x_value: $scatter_x_value,
                scatter_y_value: $scatter_y_value,
                scatter_x_label: $scatter_x_label,
                scatter_y_label: $scatter_y_label,
                ratio_x_value: $ratio_x_value,
                ratio_y_value: $ratio_y_value,
                ratio_x_label: $ratio_x_label,
                ratio_y_label: $ratio_y_label,
                comparison_x_value: $comparison_x_value,
                comparison_y_value: $comparison_y_value,
                comparison_x_label: $comparison_x_label,
                comparison_y_label: $comparison_y_label,
                dates: $dates,
                multiple_run_predictions_length: $multiple_run_predictions_length,
                plot_name: $plot_name
            ) {
                success
                errors
                    plots {
      plot_num
      plot_image
      plot_trend_slope
      plot_trend_intercept
      plot_trend_correlation
      plot_trend_standard_deviation
      plot_trend_dispersion
    }
            }
        }
    """

    variables = {
        "scatter_x_value": scatter_x_value,
        "scatter_y_value": scatter_y_value,
        "scatter_x_label": scatter_x_label,
        "scatter_y_label": scatter_y_label,
        "ratio_x_value": ratio_x_value,
        "ratio_y_value": ratio_y_value,
        "ratio_x_label": ratio_x_label,
        "ratio_y_label": ratio_y_label,
        "comparison_x_value": comparison_x_value,
        "comparison_y_value": comparison_y_value,
        "comparison_x_label": comparison_x_label,
        "comparison_y_label": comparison_y_label,
        "dates": dates,
        "multiple_run_predictions_length": multiple_run_predictions_length,
        "plot_name" : plot_name
    }
    data = {
        'query': query,
        'variables' : variables
    }

    response = requests.post('http://3.64.122.73:5002/graphql',headers=headers,json=data)
    print(response.text)
    return response.json()

# %%
y_actual = inv_test['MPN5P'].tolist()
y_pred = inv_test['Preds MPN5P'].tolist()

response = TPG_Trigger(
    scatter_x_value=y_actual,
    scatter_y_value=y_pred,
    scatter_x_label='X',
    scatter_y_label='Y',
    ratio_x_value=y_actual,
    ratio_y_value=y_pred,
    ratio_x_label='X',
    ratio_y_label='Y',
    comparison_x_value=y_actual,
    comparison_y_value=y_pred,
    comparison_x_label='X',
    comparison_y_label='Y',
    dates=dates,
    multiple_run_predictions_length = len(y_pred),
    plot_name='LTM_pretreated_features'
)

print(response)
# Out:
# {
#   "data": {
#     "plotme": {
#       "errors": null,
#       "plots": [
#         {
#           "plot_image": "...",
#           "plot_num": 1,
#           "plot_trend_correlation": 1.0,
#           "plot_trend_dispersion": 1.0,
#           "plot_trend_intercept": 1.0,
#           "plot_trend_slope": 1.0,
#           "plot_trend_standard_deviation": 0.8074
#         },
#         {
#           "plot_image": "...",
#           "plot_num": 2,
#           "plot_trend_correlation": 1.0,
#           "plot_trend_dispersion": 1.0,
#           "plot_trend_intercept": 1.0,
#           "plot_trend_slope": 1.0,
#           "plot_trend_standard_deviation": 0.8074
#         },
#         {
#           "plot_image": "...",
#           "plot_num": 3,
#           "plot_trend_correlation": 1.0,
#           "plot_trend_dispersion": 1.0,
#           "plot_trend_intercept": 1.0,
#           "plot_trend_slope": 1.0,
#           "plot_trend_standard_deviation": 0.8074
#         }
#       ],
#       "success": true
#     }
#   }
# }
#
# {'data': {'plotme': {'errors': None, 'plots': [{'plot_image': '...', 'plot_num': 1, 'plot_trend_correlation': 1.0, 'plot_trend_dispersion': 1.0, 'plot_trend_intercept': 1.0, 'plot_trend_slope': 1.0, 'plot_trend_standard_deviation': 0.8074}, {'plot_image': '...', 'plot_num': 2, 'plot_trend_correlation': 1.0, 'plot_trend_dispersion': 1.0, 'plot_trend_intercept': 1.0, 'plot_trend_slope': 1.0, 'plot_trend_standard_deviation': 0.8074}, {'plot_image': '...', 'plot_num': 3, 'plot_trend_correlation': 1.0, 'plot_trend_dispersion': 1.0, 'plot_trend_intercept': 1.0, 'plot_trend_slope': 1.0, 'plot_trend_standard_deviation': 0.8074}], 'success': True}}}
