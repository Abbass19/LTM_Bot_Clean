# %%
import os
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import LSTM,Dense
from keras.backend import clear_session
import tensorflow as tf

warnings.simplefilter('ignore')
plt.style.use('fivethirtyeight')

# %%
data_dir = Path('data')

df = pd.read_csv(
    data_dir / 'SPP_MSFT.csv',
    usecols=['DNCP','OPCP','HPCP','LPCP','CPCP','ACPCP','VTCP','MPN5P']
)

df['DATE'] = pd.to_datetime(df['DNCP'], origin='1899-12-30', unit='D')
df = df.drop('DNCP',axis=1)
df = df.set_index('DATE')

df.head()
# Out:
#                 OPCP       HPCP      LPCP      CPCP      ACPCP       VTCP  \
# DATE
# 2000-02-29  45.87500  45.875000  44.43750  44.68750  27.880445   58437400
# 2000-03-01  44.81250  47.046875  44.46875  45.40625  28.328880  106889800
# 2000-03-02  45.90625  47.687500  45.56250  46.68750  29.128248  106932600
# 2000-03-03  47.37500  49.437500  46.93750  48.06250  29.986110  101435200
# 2000-03-06  48.00000  48.687500  45.06250  45.31250  28.270390   93609400
#
#                 MPN5P
# DATE
# 2000-02-29  46.765625
# 2000-03-01  47.070312
# 2000-03-02  47.656250
# 2000-03-03  48.000000
# 2000-03-06  48.750000

# %% [markdown]
# #### Prepare the dataset

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    #input sequence
    for i in range(n_in,0,-1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    #forecast sequence
    for i in range(0,n_out):
        cols.append(df.shift(-i))
        if i==0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]

    agg = pd.concat(cols,axis=1)
    agg.columns = names
    if dropnan:
        agg.dropna(inplace=True)

    return agg

# %%
#scale
data = df.values
data = data.astype('float32')

scaler = MinMaxScaler(feature_range=(0,1))
data = scaler.fit_transform(data)

dataset = series_to_supervised(data=data,n_in=60,n_out=1)

dataset.head()
# Out:
#     var1(t-60)  var2(t-60)  var3(t-60)  var4(t-60)  var5(t-60)  var6(t-60)  \
# 60    0.091262    0.090085    0.090329    0.088715    0.049014    0.087405
# 61    0.088101    0.093574    0.090425    0.090873    0.050345    0.170424
# 62    0.091355    0.095482    0.093766    0.094721    0.052719    0.170498
# 63    0.095725    0.100692    0.097967    0.098851    0.055267    0.161078
# 64    0.097584    0.098459    0.092239    0.090592    0.050172    0.147669
#
#     var7(t-60)  var1(t-59)  var2(t-59)  var3(t-59)  ...  var5(t-1)  var6(t-1)  \
# 60    0.095920    0.088101    0.093574    0.090425  ...   0.024753   0.086592
# 61    0.096857    0.091355    0.095482    0.093766  ...   0.026953   0.133744
# 62    0.098659    0.095725    0.100692    0.097967  ...   0.023190   0.148936
# 63    0.099716    0.097584    0.098459    0.092239  ...   0.023132   0.082924
# 64    0.102022    0.097770    0.098645    0.095007  ...   0.024927   0.104709
#
#     var7(t-1)   var1(t)   var2(t)   var3(t)   var4(t)   var5(t)   var6(t)  \
# 60   0.048957  0.048681  0.052587  0.050805  0.052955  0.026953  0.133744
# 61   0.048957  0.050819  0.049888  0.047941  0.046854  0.023190  0.148936
# 62   0.049966  0.047100  0.046725  0.046795  0.046760  0.023132  0.082924
# 63   0.051384  0.047658  0.048958  0.049277  0.049670  0.024927  0.104709
# 64   0.053594  0.049448  0.048330  0.049373  0.048449  0.024174  0.081461
#
#      var7(t)
# 60  0.048957
# 61  0.049966
# 62  0.051384
# 63  0.053594
# 64  0.054849
#
# [5 rows x 427 columns]

# %%
dataset = dataset.values

# train test split
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size

train,test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
X_train,y_train = train[:,:-1], train[:,-1]
X_test, y_test = test[:,:-1], test[:,-1]

# reshape input to be 3D [samples, timesteps, features]
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (3897, 1, 426) (3897,) (1920, 1, 426) (1920,)

# %% [markdown]
# #### Build the Model

# %%
from keras.metrics import RootMeanSquaredError

clear_session()

model = Sequential([
    LSTM(50,return_sequences=True, input_shape=(X_train.shape[1],X_train.shape[2])),
    LSTM(50,return_sequences=False),
    Dense(25),
    Dense(1)
])

model.compile(
    optimizer='Adam',
    loss='mean_squared_error',
    metrics=[RootMeanSquaredError()]
)

# %%
history = model.fit(X_train,
                    y_train,
                    batch_size=1,
                    validation_data=(X_test,y_test),
                    verbose=2,
                    epochs=20)

model.save('models/raw_features_lstmv1.h5')
# Out:
# Epoch 1/20
# 3897/3897 - 26s - loss: 4.7103e-05 - root_mean_squared_error: 0.0069 - val_loss: 0.1475 - val_root_mean_squared_error: 0.3840 - 26s/epoch - 7ms/step
# Epoch 2/20
# 3897/3897 - 17s - loss: 2.1412e-05 - root_mean_squared_error: 0.0046 - val_loss: 0.1537 - val_root_mean_squared_error: 0.3921 - 17s/epoch - 4ms/step
# Epoch 3/20
# 3897/3897 - 17s - loss: 1.7789e-05 - root_mean_squared_error: 0.0042 - val_loss: 0.1605 - val_root_mean_squared_error: 0.4006 - 17s/epoch - 4ms/step
# Epoch 4/20
# 3897/3897 - 17s - loss: 1.4719e-05 - root_mean_squared_error: 0.0038 - val_loss: 0.1577 - val_root_mean_squared_error: 0.3971 - 17s/epoch - 4ms/step
# Epoch 5/20
# 3897/3897 - 17s - loss: 1.3106e-05 - root_mean_squared_error: 0.0036 - val_loss: 0.1595 - val_root_mean_squared_error: 0.3994 - 17s/epoch - 4ms/step
# Epoch 6/20
# 3897/3897 - 17s - loss: 1.3003e-05 - root_mean_squared_error: 0.0036 - val_loss: 0.1686 - val_root_mean_squared_error: 0.4106 - 17s/epoch - 4ms/step
# Epoch 7/20
# 3897/3897 - 17s - loss: 1.1641e-05 - root_mean_squared_error: 0.0034 - val_loss: 0.1678 - val_root_mean_squared_error: 0.4096 - 17s/epoch - 4ms/step
# Epoch 8/20
# 3897/3897 - 17s - loss: 1.1126e-05 - root_mean_squared_error: 0.0033 - val_loss: 0.1676 - val_root_mean_squared_error: 0.4094 - 17s/epoch - 4ms/step
# Epoch 9/20
# 3897/3897 - 17s - loss: 1.0439e-05 - root_mean_squared_error: 0.0032 - val_loss: 0.1754 - val_root_mean_squared_error: 0.4189 - 17s/epoch - 4ms/step
# Epoch 10/20
# 3897/3897 - 17s - loss: 1.1392e-05 - root_mean_squared_error: 0.0034 - val_loss: 0.1712 - val_root_mean_squared_error: 0.4137 - 17s/epoch - 4ms/step
# Epoch 11/20
# 3897/3897 - 17s - loss: 9.5803e-06 - root_mean_squared_error: 0.0031 - val_loss: 0.1730 - val_root_mean_squared_error: 0.4159 - 17s/epoch - 4ms/step
# Epoch 12/20
# 3897/3897 - 17s - loss: 1.0676e-05 - root_mean_squared_error: 0.0033 - val_loss: 0.1751 - val_root_mean_squared_error: 0.4184 - 17s/epoch - 4ms/step
# Epoch 13/20
# 3897/3897 - 17s - loss: 9.2852e-06 - root_mean_squared_error: 0.0030 - val_loss: 0.1765 - val_root_mean_squared_error: 0.4202 - 17s/epoch - 4ms/step
# Epoch 14/20
# 3897/3897 - 17s - loss: 1.0014e-05 - root_mean_squared_error: 0.0032 - val_loss: 0.1763 - val_root_mean_squared_error: 0.4199 - 17s/epoch - 4ms/step
# Epoch 15/20
# 3897/3897 - 17s - loss: 9.0365e-06 - root_mean_squared_error: 0.0030 - val_loss: 0.1790 - val_root_mean_squared_error: 0.4231 - 17s/epoch - 4ms/step
# Epoch 16/20
# 3897/3897 - 17s - loss: 9.6833e-06 - root_mean_squared_error: 0.0031 - val_loss: 0.1746 - val_root_mean_squared_error: 0.4179 - 17s/epoch - 4ms/step
# Epoch 17/20
# 3897/3897 - 17s - loss: 9.3707e-06 - root_mean_squared_error: 0.0031 - val_loss: 0.1741 - val_root_mean_squared_error: 0.4172 - 17s/epoch - 4ms/step
# Epoch 18/20
# 3897/3897 - 17s - loss: 8.7771e-06 - root_mean_squared_error: 0.0030 - val_loss: 0.1766 - val_root_mean_squared_error: 0.4203 - 17s/epoch - 4ms/step
# Epoch 19/20
# 3897/3897 - 17s - loss: 8.2695e-06 - root_mean_squared_error: 0.0029 - val_loss: 0.1765 - val_root_mean_squared_error: 0.4201 - 17s/epoch - 4ms/step
# Epoch 20/20
# 3897/3897 - 17s - loss: 8.5142e-06 - root_mean_squared_error: 0.0029 - val_loss: 0.1775 - val_root_mean_squared_error: 0.4213 - 17s/epoch - 4ms/step

# %% [markdown]
# #### Model Evaluation

# %%
history_df = pd.DataFrame(history.history)

plt.rc(
    'lines',
    linewidth=2
)

fig,(ax1,ax2) = plt.subplots(2,1,figsize=(12,6),sharex=True)

history_df['loss'].plot(ax=ax1, label='Train loss')
history_df['val_loss'].plot(ax=ax1, label='Val loss')
ax1.legend()

history_df['root_mean_squared_error'].plot(ax=ax2, label='Train RMSE')
history_df['val_root_mean_squared_error'].plot(ax=ax2, label='Val RMSE')
ax2.legend()

plt.show()

# %% [markdown]
# #### Post Processing and Prediction

# %%
from keras.models import load_model
model = load_model('models/raw_features_lstmv1.h5')

preds = model.predict(X_test)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[2])
inv_preds = np.concatenate((preds,X_test[:,1:]),axis=1)
inv_preds = scaler.inverse_transform(inv_preds)

inv_preds
# Out:
# 60/60 [==============================] - 1s 2ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-6ab010096a2c> in <cell line: 7>()
#       5 X_test = X_test.reshape(X_test.shape[0],X_test.shape[2])
#       6 inv_preds = np.concatenate((preds,X_test[:,1:]),axis=1)
# ----> 7 inv_preds = scaler.inverse_transform(inv_preds)
#       8
#       9 inv_preds
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     539         )
#     540
# --> 541         X -= self.min_
#     542         X /= self.scale_
#     543         return X
#
# ValueError: operands could not be broadcast together with shapes (1920,426) (7,) (1920,426)

# %%
inv_preds.shape
# Out:
# (1920, 426)

# %%
X_test
# Out:
# array([[[0.07976317, 0.08104809, 0.080011  , ..., 0.11650397,
#          0.10947396, 0.03550832]],
#
#        [[0.08339284, 0.08435313, 0.08572388, ..., 0.11725484,
#          0.11013795, 0.05092639]],
#
#        [[0.08389862, 0.08494864, 0.08712919, ..., 0.11725484,
#          0.11013795, 0.03565687]],
#
#        ...,
#
#        [[0.8152089 , 0.8157809 , 0.8243973 , ..., 0.97948635,
#          0.9797163 , 0.03552888]],
#
#        [[0.80492085, 0.8046747 , 0.8149879 , ..., 0.96732235,
#          0.9676887 , 0.0235762 ]],
#
#        [[0.8020648 , 0.8080691 , 0.8159655 , ..., 0.9511337 ,
#          0.9516814 , 0.04335374]]], dtype=float32)
